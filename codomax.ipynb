# %% [markdown]
# <a href="https://colab.research.google.com/github/shravanrahane-collab/codomax/blob/main/codomax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Create sample dataset
data = {
    "Name": ["Amit", "Rahul", "Sneha", "Priya", "Om"],
    "Age": [19, 20, np.nan, 19, 20],
    "Marks": [85, 72, 90, np.nan, 88]
}

df = pd.DataFrame(data)

# Display dataset
print("Original Dataset:")
print(df)

# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Fill missing values
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# Statistical analysis
print("\nDataset Summary:")
print(df.describe())

# Sort by marks
df = df.sort_values("Marks", ascending=False)

print("\nFinal Dataset:")
print(df)
# Out:
# Original Dataset:
#     Name   Age  Marks
# 0   Amit  19.0   85.0
# 1  Rahul  20.0   72.0
# 2  Sneha   NaN   90.0
# 3  Priya  19.0    NaN
# 4     Om  20.0   88.0
#
# Missing Values:
# Name     0
# Age      1
# Marks    1
# dtype: int64
#
# Dataset Summary:
#         Age     Marks
# count   5.0   5.00000
# mean   19.5  83.75000
# std     0.5   7.01338
# min    19.0  72.00000
# 25%    19.0  83.75000
# 50%    19.5  85.00000
# 75%    20.0  88.00000
# max    20.0  90.00000
#
# Final Dataset:
#     Name   Age  Marks
# 2  Sneha  19.5  90.00
# 4     Om  20.0  88.00
# 0   Amit  19.0  85.00
# 3  Priya  19.0  83.75
# 1  Rahul  20.0  72.00
